# %%
import sys
import os
from pathlib import Path
import csv
from datetime import datetime
sys.path.append(os.path.abspath("../files")) 
sys.path.append(os.path.abspath("../src")) 
from functions.functions_A import *
from functions.functions_B import *
from utils.constantes import DATA_PATH

# %%
"""
Main principal para el procesamiento y análisis de datos de hogares e individuos. Acá se encuentra
el flujo principal de ejecución del programa, que se divide en dos secciones:
- Sección A: Transformación de archivos TXT a CSV (datasets)
- Sección B: Análisis de los datasets (hogares e individuos) mediante funciones que realizan distintos cálculos 
e informes estadísticos sobre educación, condiciones habitacionales, desocupación etc.
"""

folder_path = Path('../files')
new_folder_path = Path ('../files_out')
 
## Comentar por si quieren probar la Sección B sin tener que generar los archivos una y otra vez
# Llamamos a una función para que nos una los distintos archivos, una vez unidos los guardamos cada uno en una lista.
# -------------------Sección A----------------------------
# Para individuos
# transform_files("usu_individual_*.txt", folder_path, "usu_individuales.csv", apply_changes_individuos)

# # # Para hogares 
# transform_files("usu_hogar_*.txt", folder_path, "usu_hogares.csv", apply_changes_hogares)
# ## Comentar por si quieren probar la Sección B sin tener que generar los archivos una y otra vez


# # -------------------Sección B----------------------------

# # COMENTAR Y DESCOMENTAR ASÍ NO LO TOMA COMO MERGE 
# # Seccion B
# Ejecutamos las funciones solicitadas en la sección B.
# process_csv(new_folder_path)
# Out:
# -----------------Sección B - Ejercicio 01-------------------------
# Porcentaje de alfabetas en el año 2023: % 99.01
# Porcentaje de analfabetas en el año 2023: % 0.99
# -----------------Sección B - Ejercicio 02-------------------------
# porcentaje de extranjeros que cursaron el nivel universitario o superior es del %6.67
# -----------------Sección B - Ejercicio 03-------------------------
# en el año 2023 trimestre 1 tuvo la menor cantidad de desocupados, siendo 131
# -----------------Sección B - Ejercicio 04-------------------------
# Usando datos del trimestre 3 del año 2024
#
# Top 5 aglomerados con mayor porcentaje de hogares con al menos dos personas con universidad completa:
# Ciudad Autónoma de Buenos Aires: 57.29%
# Mar del Plata: 37.13%
# Gran Paraná: 36.12%
# Gran Mendoza: 35.99%
# Jujuy - Palpalá: 35.81%
# --------------------Sección B - Ejercicio 05----------------------------------
# Aglomerado     % Propietarios
# ------------------------------
# La Rioja: 72.71%
# ...
